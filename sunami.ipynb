# %% [markdown]
# <a href="https://colab.research.google.com/github/sunami20/Django-Project24/blob/main/sunami.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome To Sunami Industry**

# %%
print("sunami industry")
# Out:
# sunami industry
